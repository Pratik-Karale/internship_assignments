# %% [markdown]
# # Assignment No 6: Advanced Data Visualization
# Using the Iris dataset to create various visual representations.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv('Iris.csv')
iris = iris.drop('Id', axis=1)

# %%
sns.pairplot(iris, hue='Species', palette='Set2')
plt.suptitle('Pair Plot of Iris Features', y=1.02)

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='Species', y='SepalLengthCm', data=iris)
plt.title('Sepal Length Distribution by Species')

# %%
plt.figure(figsize=(10,7))
sns.violinplot(x='Species', y='PetalLengthCm', data=iris, inner='quartile')
plt.title('Petal Length Density Plot')
